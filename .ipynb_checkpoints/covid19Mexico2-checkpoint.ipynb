# %% [markdown]
# #Analisis de COVID19 en México
#
# Vamos a hacer un analisis de los datos de COVID19 en la Ciudad de México para ver cual ha sido el incremento en el número de casos por dia
#
# El objetivo es ver si las medidas de contención estan funcionando, pues los porcentajes sobre numeros cada vez mayoers no son indicadores claros del crecimiento de la enfermedad.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import requests
page=requests.get("https://en.wikipedia.org/wiki/Timeline_of_the_COVID-19_pandemic_in_Mexico")
print("Requests :", page.status_code)
#Luego creamos un par de listas vacias para guardar los datos
enfermos = []
muertos = []
#obtenemos el contenido
contenido = page.content
# y lo pasamos al BeautifulSoup
soup = bs(contenido, 'html.parser') #esta es toda la sopa en html
### en julio cambiaron el formato de la tabla
#datos=soup.find_all('span', class_='cbs-ibr') #inspecionamos (inspect from chrome) para saber el elemento que queremos
#fechas=soup.find_all('td', class_='bb-04em')
### Debido al cambio de julio ahora tenemos
fechas=soup.find_all('td', class_='bb-c')
enfermos=soup.find_all('span', class_='mcc-rw')
muertos=soup.find_all('span', class_='mcc-rm')
for i in range(0,6):
    print(i,fechas[i].get_text())
    print(i,enfermos[i].get_text())

#print("datos: ",datos)
print("fechas: ", type(fechas))

print(f"Numero de datos recuperados {len(datos)}, enfermos + muertos") #numero de datos en la lista, enfermos y muertos
#como la informacion viene revuelta, los pares son enfermos y los nones son muertos

for i in range(0,len(datos)):
    if i%2==0:
        #Tenemos datos en forma de string, por lo que tenemos que extraer el texto del tag de html (get_text()), 
        #luego eliminar las comas (string.replace(',','')) y finalemnte convetir el resultado a un numero
        #float(string)
        enfermos.append(float(datos[i].get_text().replace(',','')))
    else:
        aux=datos[i].get_text().replace(',','')
        if aux.isnumeric():
            muertos.append(float(aux))
        else:
            muertos.append(0)

#print(fechas[0])
#print(fechas[3])
#print(fechas[6])
#print(fechas[9])
#print(fechas[12].get_text())
#Tenemos las fechas cada multiplo de tres. Y los primeros dias faltan algunos datos, empiezan a ser estables
#a partir de el 2020-03-11
#vamos a usar un contador y un while

#Lista de Fechas
dates=[]
i=0 #Contador Generico
while i < len(fechas):
    dates.append(fechas[i].get_text())
    i=i+3
# Out:
# Requests : 200
# 0 2020-02-28
# 0 [<span class="mcc-rw">3</span>, <span class="mcc-rw">4</span>, <span class="mcc-rw">5</span>, <span class="mcc-rw">5</span>, <span class="mcc-rw">6</span>, <span class="mcc-rw">7</span>, <span class="mcc-rw">7</span>, <span class="mcc-rw">11</span>, <span class="mcc-rw">15</span>, <span class="mcc-rw">26</span>, <span class="mcc-rw">41</span>, <span class="mcc-rw">53</span>, <span class="mcc-rw">78</span>, <span class="mcc-rw">89</span>, <span class="mcc-rw">118</span>, <span class="mcc-rw">164</span>, <span class="mcc-rw">203</span>, <span class="mcc-rw">251</span>, <span class="mcc-rw">316</span>, <span class="mcc-rw">367</span>, <span class="mcc-rw">405</span>, <span class="mcc-rw">475</span>, <span class="mcc-rw">585</span>, <span class="mcc-rw">717</span>, <span class="mcc-rw">848</span>, <span class="mcc-rw">993</span>, <span class="mcc-rw">1,094</span>, <span class="mcc-rw">1,215</span>, <span class="mcc-rw">1,378</span>, <span class="mcc-rw">1,510</span>, <span class="mcc-rw">1,688</span>, <span class="mcc-rw">1,890</span>, <span class="mcc-rw">2,143</span>, <span class="mcc-rw">2,439</span>, <span class="mcc-rw">2,785</span>, <span class="mcc-rw">3,181</span>, <span class="mcc-rw">3,441</span>, <span class="mcc-rw">3,844</span>, <span class="mcc-rw">4,219</span>, <span class="mcc-rw">4,661</span>, <span class="mcc-rw">5,014</span>, <span class="mcc-rw">5,399</span>, <span class="mcc-rw">5,847</span>, <span class="mcc-rw">6,297</span>, <span class="mcc-rw">6,875</span>, <span class="mcc-rw">7,497</span>, <span class="mcc-rw">8,261</span>, <span class="mcc-rw">8,772</span>, <span class="mcc-rw">9,501</span>, <span class="mcc-rw">10,544</span>, <span class="mcc-rw">11,633</span>, <span class="mcc-rw">12,872</span>, <span class="mcc-rw">13,842</span>, <span class="mcc-rw">14,677</span>, <span class="mcc-rw">15,529</span>, <span class="mcc-rw">16,752</span>, <span class="mcc-rw">17,799</span>, <span class="mcc-rw">19,224</span>, <span class="mcc-rw">20,739</span>, <span class="mcc-rw">22,088</span>, <span class="mcc-rw">23,471</span>, <span class="mcc-rw">24,905</span>, <span class="mcc-rw">26,025</span>, <span class="mcc-rw">27,634</span>, <span class="mcc-rw">29,616</span>, <span class="mcc-rw">31,522</span>, <span class="mcc-rw">33,460</span>, <span class="mcc-rw">35,022</span>, <span class="mcc-rw">36,327</span>, <span class="mcc-rw">38,324</span>, <span class="mcc-rw">40,186</span>, <span class="mcc-rw">42,595</span>, <span class="mcc-rw">45,032</span>, <span class="mcc-rw">47,144</span>, <span class="mcc-rw">49,219</span>, <span class="mcc-rw">51,633</span>, <span class="mcc-rw">54,346</span>, <span class="mcc-rw">56,594</span>, <span class="mcc-rw">59,567</span>, <span class="mcc-rw">62,527</span>, <span class="mcc-rw">65,856</span>, <span class="mcc-rw">68,620</span>, <span class="mcc-rw">71,105</span>, <span class="mcc-rw">74,560</span>, <span class="mcc-rw">78,023</span>, <span class="mcc-rw">81,400</span>, <span class="mcc-rw">84,627</span>, <span class="mcc-rw">87,512</span>, <span class="mcc-rw">90,664</span>, <span class="mcc-rw">93,435</span>, <span class="mcc-rw">97,326</span>, <span class="mcc-rw">101,238</span>, <span class="mcc-rw">105,680</span>, <span class="mcc-rw">110,026</span>, <span class="mcc-rw">113,619</span>, <span class="mcc-rw">117,103</span>, <span class="mcc-rw">120,102</span>, <span class="mcc-rw">124,301</span>, <span class="mcc-rw">129,184</span>, <span class="mcc-rw">133,974</span>, <span class="mcc-rw">139,196</span>, <span class="mcc-rw">142,690</span>, <span class="mcc-rw">146,837</span>, <span class="mcc-rw">150,264</span>, <span class="mcc-rw">154,863</span>, <span class="mcc-rw">159,793</span>, <span class="mcc-rw">165,455</span>, <span class="mcc-rw">170,485</span>, <span class="mcc-rw">175,202</span>, <span class="mcc-rw">180,545</span>, <span class="mcc-rw">185,122</span>, <span class="mcc-rw">191,410</span>, <span class="mcc-rw">196,847</span>, <span class="mcc-rw">202,951< ...
# 0 [<span class="mcc-rm">1</span>, <span class="mcc-rm">1</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">4</span>, <span class="mcc-rm">5</span>, <span class="mcc-rm">6</span>, <span class="mcc-rm">8</span>, <span class="mcc-rm">12</span>, <span class="mcc-rm">16</span>, <span class="mcc-rm">20</span>, <span class="mcc-rm">28</span>, <span class="mcc-rm">29</span>, <span class="mcc-rm">37</span>, <span class="mcc-rm">50</span>, <span class="mcc-rm">60</span>, <span class="mcc-rm">79</span>, <span class="mcc-rm">94</span>, <span class="mcc-rm">125</span>, <span class="mcc-rm">141</span>, <span class="mcc-rm">174</span>, <span class="mcc-rm">194</span>, <span class="mcc-rm">233</span>, <span class="mcc-rm">273</span>, <span class="mcc-rm">296</span>, <span class="mcc-rm">332</span>, <span class="mcc-rm">406</span>, <span class="mcc-rm">449</span>, <span class="mcc-rm">486</span>, <span class="mcc-rm">546</span>, <span class="mcc-rm">650</span>, <span class="mcc-rm">686</span>, <span class="mcc-rm">712</span>, <span class="mcc-rm">857</span>, <span class="mcc-rm">970</span>, <span class="mcc-rm">1,069</span>, <span class="mcc-rm">1,221</span>, <span class="mcc-rm">1,305</span>, <span class="mcc-rm">1,351</span>, <span class="mcc-rm">1,434</span>, <span class="mcc-rm">1,569</span>, <span class="mcc-rm">1,732</span>, <span class="mcc-rm">1,859</span>, <span class="mcc-rm">1,972</span>, <span class="mcc-rm">2,061</span>, <span class="mcc-rm">2,154</span>, <span class="mcc-rm">2,271</span>, <span class="mcc-rm">2,507</span>, <span class="mcc-rm">2,704</span>, <span class="mcc-rm">2,961</span>, <span class="mcc-rm">3,160</span>, <span class="mcc-rm">3,353</span>, <span class="mcc-rm">3,465</span>, <span class="mcc-rm">3,573</span>, <span class="mcc-rm">3,926</span>, <span class="mcc-rm">4,220</span>, <span class="mcc-rm">4,477</span>, <span class="mcc-rm">4,767</span>, <span class="mcc-rm">5,045</span>, <span class="mcc-rm">5,177</span>, <span class="mcc-rm">5,332</span>, <span class="mcc-rm">5,666</span>, <span class="mcc-rm">6,090</span>, <span class="mcc-rm">6,510</span>, <span class="mcc-rm">6,989</span>, <span class="mcc-rm">7,179</span>, <span class="mcc-rm">7,394</span>, <span class="mcc-rm">7,633</span>, <span class="mcc-rm">8,134</span>, <span class="mcc-rm">8,597</span>, <span class="mcc-rm">9,044</span>, <span class="mcc-rm">9,415</span>, <span class="mcc-rm">9,779</span>, <span class="mcc-rm">9,930</span>, <span class="mcc-rm">10,167</span>, <span class="mcc-rm">10,637</span>, <span class="mcc-rm">11,729</span>, <span class="mcc-rm">12,545</span>, <span class="mcc-rm">13,170</span>, <span class="mcc-rm">13,511</span>, <span class="mcc-rm">13,699</span>, <span class="mcc-rm">14,053</span>, <span class="mcc-rm">14,649</span>, <span class="mcc-rm">15,357</span>, <span class="mcc-rm">15,944</span>, <span class="mcc-rm">16,448</span>, <span class="mcc-rm">16,872</span>, <span class="mcc-rm">17,141</span>, <span class="mcc-rm">17,580</span>, <span class="mcc-rm">18,310</span>, <span class="mcc-rm">19,080</span>, <span class="mcc-rm">19,747</span>, <span class="mcc-rm">20,394</span>, <span class="mcc-rm">20,781</span>, <span class="mcc-rm">21,825</span>, <span class="mcc-rm">22,584</span>, <span class="mcc-rm">23,377</span>, <span class="mcc-rm">24,324</span>, <span class="mcc-rm">25,060</span>, <span class="mcc-rm">25,779</span>, <span class="mcc-rm">26,381</span>, <span class="mcc-rm">26,648</span>, <span class="mcc-rm">27,121</span>, <span class="mcc-rm">27,769</span>, <span class="mcc-rm">28,510</span>, <span class="mcc-rm">29,189</span>, <span class="mcc-rm">29,843</span>, <span class="mcc-rm">30,366</span>, <span class="mcc-rm">30,639</span>, <span class="mcc-rm">31,119</span>, <span class="mcc-rm">32,014</span>, <span class="mcc-rm">32,796</span>, <span class="mcc-rm">33,526</span>, <span class="mcc-rm">34,191</span>, <span class="mcc-rm">34,730</spa ...
# 1 3(n.a.)
# 1 [<span class="mcc-rw">3</span>, <span class="mcc-rw">4</span>, <span class="mcc-rw">5</span>, <span class="mcc-rw">5</span>, <span class="mcc-rw">6</span>, <span class="mcc-rw">7</span>, <span class="mcc-rw">7</span>, <span class="mcc-rw">11</span>, <span class="mcc-rw">15</span>, <span class="mcc-rw">26</span>, <span class="mcc-rw">41</span>, <span class="mcc-rw">53</span>, <span class="mcc-rw">78</span>, <span class="mcc-rw">89</span>, <span class="mcc-rw">118</span>, <span class="mcc-rw">164</span>, <span class="mcc-rw">203</span>, <span class="mcc-rw">251</span>, <span class="mcc-rw">316</span>, <span class="mcc-rw">367</span>, <span class="mcc-rw">405</span>, <span class="mcc-rw">475</span>, <span class="mcc-rw">585</span>, <span class="mcc-rw">717</span>, <span class="mcc-rw">848</span>, <span class="mcc-rw">993</span>, <span class="mcc-rw">1,094</span>, <span class="mcc-rw">1,215</span>, <span class="mcc-rw">1,378</span>, <span class="mcc-rw">1,510</span>, <span class="mcc-rw">1,688</span>, <span class="mcc-rw">1,890</span>, <span class="mcc-rw">2,143</span>, <span class="mcc-rw">2,439</span>, <span class="mcc-rw">2,785</span>, <span class="mcc-rw">3,181</span>, <span class="mcc-rw">3,441</span>, <span class="mcc-rw">3,844</span>, <span class="mcc-rw">4,219</span>, <span class="mcc-rw">4,661</span>, <span class="mcc-rw">5,014</span>, <span class="mcc-rw">5,399</span>, <span class="mcc-rw">5,847</span>, <span class="mcc-rw">6,297</span>, <span class="mcc-rw">6,875</span>, <span class="mcc-rw">7,497</span>, <span class="mcc-rw">8,261</span>, <span class="mcc-rw">8,772</span>, <span class="mcc-rw">9,501</span>, <span class="mcc-rw">10,544</span>, <span class="mcc-rw">11,633</span>, <span class="mcc-rw">12,872</span>, <span class="mcc-rw">13,842</span>, <span class="mcc-rw">14,677</span>, <span class="mcc-rw">15,529</span>, <span class="mcc-rw">16,752</span>, <span class="mcc-rw">17,799</span>, <span class="mcc-rw">19,224</span>, <span class="mcc-rw">20,739</span>, <span class="mcc-rw">22,088</span>, <span class="mcc-rw">23,471</span>, <span class="mcc-rw">24,905</span>, <span class="mcc-rw">26,025</span>, <span class="mcc-rw">27,634</span>, <span class="mcc-rw">29,616</span>, <span class="mcc-rw">31,522</span>, <span class="mcc-rw">33,460</span>, <span class="mcc-rw">35,022</span>, <span class="mcc-rw">36,327</span>, <span class="mcc-rw">38,324</span>, <span class="mcc-rw">40,186</span>, <span class="mcc-rw">42,595</span>, <span class="mcc-rw">45,032</span>, <span class="mcc-rw">47,144</span>, <span class="mcc-rw">49,219</span>, <span class="mcc-rw">51,633</span>, <span class="mcc-rw">54,346</span>, <span class="mcc-rw">56,594</span>, <span class="mcc-rw">59,567</span>, <span class="mcc-rw">62,527</span>, <span class="mcc-rw">65,856</span>, <span class="mcc-rw">68,620</span>, <span class="mcc-rw">71,105</span>, <span class="mcc-rw">74,560</span>, <span class="mcc-rw">78,023</span>, <span class="mcc-rw">81,400</span>, <span class="mcc-rw">84,627</span>, <span class="mcc-rw">87,512</span>, <span class="mcc-rw">90,664</span>, <span class="mcc-rw">93,435</span>, <span class="mcc-rw">97,326</span>, <span class="mcc-rw">101,238</span>, <span class="mcc-rw">105,680</span>, <span class="mcc-rw">110,026</span>, <span class="mcc-rw">113,619</span>, <span class="mcc-rw">117,103</span>, <span class="mcc-rw">120,102</span>, <span class="mcc-rw">124,301</span>, <span class="mcc-rw">129,184</span>, <span class="mcc-rw">133,974</span>, <span class="mcc-rw">139,196</span>, <span class="mcc-rw">142,690</span>, <span class="mcc-rw">146,837</span>, <span class="mcc-rw">150,264</span>, <span class="mcc-rw">154,863</span>, <span class="mcc-rw">159,793</span>, <span class="mcc-rw">165,455</span>, <span class="mcc-rw">170,485</span>, <span class="mcc-rw">175,202</span>, <span class="mcc-rw">180,545</span>, <span class="mcc-rw">185,122</span>, <span class="mcc-rw">191,410</span>, <span class="mcc-rw">196,847</span>, <span class="mcc-rw">202,951< ...
# 1 [<span class="mcc-rm">1</span>, <span class="mcc-rm">1</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">4</span>, <span class="mcc-rm">5</span>, <span class="mcc-rm">6</span>, <span class="mcc-rm">8</span>, <span class="mcc-rm">12</span>, <span class="mcc-rm">16</span>, <span class="mcc-rm">20</span>, <span class="mcc-rm">28</span>, <span class="mcc-rm">29</span>, <span class="mcc-rm">37</span>, <span class="mcc-rm">50</span>, <span class="mcc-rm">60</span>, <span class="mcc-rm">79</span>, <span class="mcc-rm">94</span>, <span class="mcc-rm">125</span>, <span class="mcc-rm">141</span>, <span class="mcc-rm">174</span>, <span class="mcc-rm">194</span>, <span class="mcc-rm">233</span>, <span class="mcc-rm">273</span>, <span class="mcc-rm">296</span>, <span class="mcc-rm">332</span>, <span class="mcc-rm">406</span>, <span class="mcc-rm">449</span>, <span class="mcc-rm">486</span>, <span class="mcc-rm">546</span>, <span class="mcc-rm">650</span>, <span class="mcc-rm">686</span>, <span class="mcc-rm">712</span>, <span class="mcc-rm">857</span>, <span class="mcc-rm">970</span>, <span class="mcc-rm">1,069</span>, <span class="mcc-rm">1,221</span>, <span class="mcc-rm">1,305</span>, <span class="mcc-rm">1,351</span>, <span class="mcc-rm">1,434</span>, <span class="mcc-rm">1,569</span>, <span class="mcc-rm">1,732</span>, <span class="mcc-rm">1,859</span>, <span class="mcc-rm">1,972</span>, <span class="mcc-rm">2,061</span>, <span class="mcc-rm">2,154</span>, <span class="mcc-rm">2,271</span>, <span class="mcc-rm">2,507</span>, <span class="mcc-rm">2,704</span>, <span class="mcc-rm">2,961</span>, <span class="mcc-rm">3,160</span>, <span class="mcc-rm">3,353</span>, <span class="mcc-rm">3,465</span>, <span class="mcc-rm">3,573</span>, <span class="mcc-rm">3,926</span>, <span class="mcc-rm">4,220</span>, <span class="mcc-rm">4,477</span>, <span class="mcc-rm">4,767</span>, <span class="mcc-rm">5,045</span>, <span class="mcc-rm">5,177</span>, <span class="mcc-rm">5,332</span>, <span class="mcc-rm">5,666</span>, <span class="mcc-rm">6,090</span>, <span class="mcc-rm">6,510</span>, <span class="mcc-rm">6,989</span>, <span class="mcc-rm">7,179</span>, <span class="mcc-rm">7,394</span>, <span class="mcc-rm">7,633</span>, <span class="mcc-rm">8,134</span>, <span class="mcc-rm">8,597</span>, <span class="mcc-rm">9,044</span>, <span class="mcc-rm">9,415</span>, <span class="mcc-rm">9,779</span>, <span class="mcc-rm">9,930</span>, <span class="mcc-rm">10,167</span>, <span class="mcc-rm">10,637</span>, <span class="mcc-rm">11,729</span>, <span class="mcc-rm">12,545</span>, <span class="mcc-rm">13,170</span>, <span class="mcc-rm">13,511</span>, <span class="mcc-rm">13,699</span>, <span class="mcc-rm">14,053</span>, <span class="mcc-rm">14,649</span>, <span class="mcc-rm">15,357</span>, <span class="mcc-rm">15,944</span>, <span class="mcc-rm">16,448</span>, <span class="mcc-rm">16,872</span>, <span class="mcc-rm">17,141</span>, <span class="mcc-rm">17,580</span>, <span class="mcc-rm">18,310</span>, <span class="mcc-rm">19,080</span>, <span class="mcc-rm">19,747</span>, <span class="mcc-rm">20,394</span>, <span class="mcc-rm">20,781</span>, <span class="mcc-rm">21,825</span>, <span class="mcc-rm">22,584</span>, <span class="mcc-rm">23,377</span>, <span class="mcc-rm">24,324</span>, <span class="mcc-rm">25,060</span>, <span class="mcc-rm">25,779</span>, <span class="mcc-rm">26,381</span>, <span class="mcc-rm">26,648</span>, <span class="mcc-rm">27,121</span>, <span class="mcc-rm">27,769</span>, <span class="mcc-rm">28,510</span>, <span class="mcc-rm">29,189</span>, <span class="mcc-rm">29,843</span>, <span class="mcc-rm">30,366</span>, <span class="mcc-rm">30,639</span>, <span class="mcc-rm">31,119</span>, <span class="mcc-rm">32,014</span>, <span class="mcc-rm">32,796</span>, <span class="mcc-rm">33,526</span>, <span class="mcc-rm">34,191</span>, <span class="mcc-rm">34,730</spa ...
# 2
#
# 2 [<span class="mcc-rw">3</span>, <span class="mcc-rw">4</span>, <span class="mcc-rw">5</span>, <span class="mcc-rw">5</span>, <span class="mcc-rw">6</span>, <span class="mcc-rw">7</span>, <span class="mcc-rw">7</span>, <span class="mcc-rw">11</span>, <span class="mcc-rw">15</span>, <span class="mcc-rw">26</span>, <span class="mcc-rw">41</span>, <span class="mcc-rw">53</span>, <span class="mcc-rw">78</span>, <span class="mcc-rw">89</span>, <span class="mcc-rw">118</span>, <span class="mcc-rw">164</span>, <span class="mcc-rw">203</span>, <span class="mcc-rw">251</span>, <span class="mcc-rw">316</span>, <span class="mcc-rw">367</span>, <span class="mcc-rw">405</span>, <span class="mcc-rw">475</span>, <span class="mcc-rw">585</span>, <span class="mcc-rw">717</span>, <span class="mcc-rw">848</span>, <span class="mcc-rw">993</span>, <span class="mcc-rw">1,094</span>, <span class="mcc-rw">1,215</span>, <span class="mcc-rw">1,378</span>, <span class="mcc-rw">1,510</span>, <span class="mcc-rw">1,688</span>, <span class="mcc-rw">1,890</span>, <span class="mcc-rw">2,143</span>, <span class="mcc-rw">2,439</span>, <span class="mcc-rw">2,785</span>, <span class="mcc-rw">3,181</span>, <span class="mcc-rw">3,441</span>, <span class="mcc-rw">3,844</span>, <span class="mcc-rw">4,219</span>, <span class="mcc-rw">4,661</span>, <span class="mcc-rw">5,014</span>, <span class="mcc-rw">5,399</span>, <span class="mcc-rw">5,847</span>, <span class="mcc-rw">6,297</span>, <span class="mcc-rw">6,875</span>, <span class="mcc-rw">7,497</span>, <span class="mcc-rw">8,261</span>, <span class="mcc-rw">8,772</span>, <span class="mcc-rw">9,501</span>, <span class="mcc-rw">10,544</span>, <span class="mcc-rw">11,633</span>, <span class="mcc-rw">12,872</span>, <span class="mcc-rw">13,842</span>, <span class="mcc-rw">14,677</span>, <span class="mcc-rw">15,529</span>, <span class="mcc-rw">16,752</span>, <span class="mcc-rw">17,799</span>, <span class="mcc-rw">19,224</span>, <span class="mcc-rw">20,739</span>, <span class="mcc-rw">22,088</span>, <span class="mcc-rw">23,471</span>, <span class="mcc-rw">24,905</span>, <span class="mcc-rw">26,025</span>, <span class="mcc-rw">27,634</span>, <span class="mcc-rw">29,616</span>, <span class="mcc-rw">31,522</span>, <span class="mcc-rw">33,460</span>, <span class="mcc-rw">35,022</span>, <span class="mcc-rw">36,327</span>, <span class="mcc-rw">38,324</span>, <span class="mcc-rw">40,186</span>, <span class="mcc-rw">42,595</span>, <span class="mcc-rw">45,032</span>, <span class="mcc-rw">47,144</span>, <span class="mcc-rw">49,219</span>, <span class="mcc-rw">51,633</span>, <span class="mcc-rw">54,346</span>, <span class="mcc-rw">56,594</span>, <span class="mcc-rw">59,567</span>, <span class="mcc-rw">62,527</span>, <span class="mcc-rw">65,856</span>, <span class="mcc-rw">68,620</span>, <span class="mcc-rw">71,105</span>, <span class="mcc-rw">74,560</span>, <span class="mcc-rw">78,023</span>, <span class="mcc-rw">81,400</span>, <span class="mcc-rw">84,627</span>, <span class="mcc-rw">87,512</span>, <span class="mcc-rw">90,664</span>, <span class="mcc-rw">93,435</span>, <span class="mcc-rw">97,326</span>, <span class="mcc-rw">101,238</span>, <span class="mcc-rw">105,680</span>, <span class="mcc-rw">110,026</span>, <span class="mcc-rw">113,619</span>, <span class="mcc-rw">117,103</span>, <span class="mcc-rw">120,102</span>, <span class="mcc-rw">124,301</span>, <span class="mcc-rw">129,184</span>, <span class="mcc-rw">133,974</span>, <span class="mcc-rw">139,196</span>, <span class="mcc-rw">142,690</span>, <span class="mcc-rw">146,837</span>, <span class="mcc-rw">150,264</span>, <span class="mcc-rw">154,863</span>, <span class="mcc-rw">159,793</span>, <span class="mcc-rw">165,455</span>, <span class="mcc-rw">170,485</span>, <span class="mcc-rw">175,202</span>, <span class="mcc-rw">180,545</span>, <span class="mcc-rw">185,122</span>, <span class="mcc-rw">191,410</span>, <span class="mcc-rw">196,847</span>, <span class="mcc-rw">202,951< ...
# 2 [<span class="mcc-rm">1</span>, <span class="mcc-rm">1</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">4</span>, <span class="mcc-rm">5</span>, <span class="mcc-rm">6</span>, <span class="mcc-rm">8</span>, <span class="mcc-rm">12</span>, <span class="mcc-rm">16</span>, <span class="mcc-rm">20</span>, <span class="mcc-rm">28</span>, <span class="mcc-rm">29</span>, <span class="mcc-rm">37</span>, <span class="mcc-rm">50</span>, <span class="mcc-rm">60</span>, <span class="mcc-rm">79</span>, <span class="mcc-rm">94</span>, <span class="mcc-rm">125</span>, <span class="mcc-rm">141</span>, <span class="mcc-rm">174</span>, <span class="mcc-rm">194</span>, <span class="mcc-rm">233</span>, <span class="mcc-rm">273</span>, <span class="mcc-rm">296</span>, <span class="mcc-rm">332</span>, <span class="mcc-rm">406</span>, <span class="mcc-rm">449</span>, <span class="mcc-rm">486</span>, <span class="mcc-rm">546</span>, <span class="mcc-rm">650</span>, <span class="mcc-rm">686</span>, <span class="mcc-rm">712</span>, <span class="mcc-rm">857</span>, <span class="mcc-rm">970</span>, <span class="mcc-rm">1,069</span>, <span class="mcc-rm">1,221</span>, <span class="mcc-rm">1,305</span>, <span class="mcc-rm">1,351</span>, <span class="mcc-rm">1,434</span>, <span class="mcc-rm">1,569</span>, <span class="mcc-rm">1,732</span>, <span class="mcc-rm">1,859</span>, <span class="mcc-rm">1,972</span>, <span class="mcc-rm">2,061</span>, <span class="mcc-rm">2,154</span>, <span class="mcc-rm">2,271</span>, <span class="mcc-rm">2,507</span>, <span class="mcc-rm">2,704</span>, <span class="mcc-rm">2,961</span>, <span class="mcc-rm">3,160</span>, <span class="mcc-rm">3,353</span>, <span class="mcc-rm">3,465</span>, <span class="mcc-rm">3,573</span>, <span class="mcc-rm">3,926</span>, <span class="mcc-rm">4,220</span>, <span class="mcc-rm">4,477</span>, <span class="mcc-rm">4,767</span>, <span class="mcc-rm">5,045</span>, <span class="mcc-rm">5,177</span>, <span class="mcc-rm">5,332</span>, <span class="mcc-rm">5,666</span>, <span class="mcc-rm">6,090</span>, <span class="mcc-rm">6,510</span>, <span class="mcc-rm">6,989</span>, <span class="mcc-rm">7,179</span>, <span class="mcc-rm">7,394</span>, <span class="mcc-rm">7,633</span>, <span class="mcc-rm">8,134</span>, <span class="mcc-rm">8,597</span>, <span class="mcc-rm">9,044</span>, <span class="mcc-rm">9,415</span>, <span class="mcc-rm">9,779</span>, <span class="mcc-rm">9,930</span>, <span class="mcc-rm">10,167</span>, <span class="mcc-rm">10,637</span>, <span class="mcc-rm">11,729</span>, <span class="mcc-rm">12,545</span>, <span class="mcc-rm">13,170</span>, <span class="mcc-rm">13,511</span>, <span class="mcc-rm">13,699</span>, <span class="mcc-rm">14,053</span>, <span class="mcc-rm">14,649</span>, <span class="mcc-rm">15,357</span>, <span class="mcc-rm">15,944</span>, <span class="mcc-rm">16,448</span>, <span class="mcc-rm">16,872</span>, <span class="mcc-rm">17,141</span>, <span class="mcc-rm">17,580</span>, <span class="mcc-rm">18,310</span>, <span class="mcc-rm">19,080</span>, <span class="mcc-rm">19,747</span>, <span class="mcc-rm">20,394</span>, <span class="mcc-rm">20,781</span>, <span class="mcc-rm">21,825</span>, <span class="mcc-rm">22,584</span>, <span class="mcc-rm">23,377</span>, <span class="mcc-rm">24,324</span>, <span class="mcc-rm">25,060</span>, <span class="mcc-rm">25,779</span>, <span class="mcc-rm">26,381</span>, <span class="mcc-rm">26,648</span>, <span class="mcc-rm">27,121</span>, <span class="mcc-rm">27,769</span>, <span class="mcc-rm">28,510</span>, <span class="mcc-rm">29,189</span>, <span class="mcc-rm">29,843</span>, <span class="mcc-rm">30,366</span>, <span class="mcc-rm">30,639</span>, <span class="mcc-rm">31,119</span>, <span class="mcc-rm">32,014</span>, <span class="mcc-rm">32,796</span>, <span class="mcc-rm">33,526</span>, <span class="mcc-rm">34,191</span>, <span class="mcc-rm">34,730</spa ...
# 3 2020-02-29
# 3 [<span class="mcc-rw">3</span>, <span class="mcc-rw">4</span>, <span class="mcc-rw">5</span>, <span class="mcc-rw">5</span>, <span class="mcc-rw">6</span>, <span class="mcc-rw">7</span>, <span class="mcc-rw">7</span>, <span class="mcc-rw">11</span>, <span class="mcc-rw">15</span>, <span class="mcc-rw">26</span>, <span class="mcc-rw">41</span>, <span class="mcc-rw">53</span>, <span class="mcc-rw">78</span>, <span class="mcc-rw">89</span>, <span class="mcc-rw">118</span>, <span class="mcc-rw">164</span>, <span class="mcc-rw">203</span>, <span class="mcc-rw">251</span>, <span class="mcc-rw">316</span>, <span class="mcc-rw">367</span>, <span class="mcc-rw">405</span>, <span class="mcc-rw">475</span>, <span class="mcc-rw">585</span>, <span class="mcc-rw">717</span>, <span class="mcc-rw">848</span>, <span class="mcc-rw">993</span>, <span class="mcc-rw">1,094</span>, <span class="mcc-rw">1,215</span>, <span class="mcc-rw">1,378</span>, <span class="mcc-rw">1,510</span>, <span class="mcc-rw">1,688</span>, <span class="mcc-rw">1,890</span>, <span class="mcc-rw">2,143</span>, <span class="mcc-rw">2,439</span>, <span class="mcc-rw">2,785</span>, <span class="mcc-rw">3,181</span>, <span class="mcc-rw">3,441</span>, <span class="mcc-rw">3,844</span>, <span class="mcc-rw">4,219</span>, <span class="mcc-rw">4,661</span>, <span class="mcc-rw">5,014</span>, <span class="mcc-rw">5,399</span>, <span class="mcc-rw">5,847</span>, <span class="mcc-rw">6,297</span>, <span class="mcc-rw">6,875</span>, <span class="mcc-rw">7,497</span>, <span class="mcc-rw">8,261</span>, <span class="mcc-rw">8,772</span>, <span class="mcc-rw">9,501</span>, <span class="mcc-rw">10,544</span>, <span class="mcc-rw">11,633</span>, <span class="mcc-rw">12,872</span>, <span class="mcc-rw">13,842</span>, <span class="mcc-rw">14,677</span>, <span class="mcc-rw">15,529</span>, <span class="mcc-rw">16,752</span>, <span class="mcc-rw">17,799</span>, <span class="mcc-rw">19,224</span>, <span class="mcc-rw">20,739</span>, <span class="mcc-rw">22,088</span>, <span class="mcc-rw">23,471</span>, <span class="mcc-rw">24,905</span>, <span class="mcc-rw">26,025</span>, <span class="mcc-rw">27,634</span>, <span class="mcc-rw">29,616</span>, <span class="mcc-rw">31,522</span>, <span class="mcc-rw">33,460</span>, <span class="mcc-rw">35,022</span>, <span class="mcc-rw">36,327</span>, <span class="mcc-rw">38,324</span>, <span class="mcc-rw">40,186</span>, <span class="mcc-rw">42,595</span>, <span class="mcc-rw">45,032</span>, <span class="mcc-rw">47,144</span>, <span class="mcc-rw">49,219</span>, <span class="mcc-rw">51,633</span>, <span class="mcc-rw">54,346</span>, <span class="mcc-rw">56,594</span>, <span class="mcc-rw">59,567</span>, <span class="mcc-rw">62,527</span>, <span class="mcc-rw">65,856</span>, <span class="mcc-rw">68,620</span>, <span class="mcc-rw">71,105</span>, <span class="mcc-rw">74,560</span>, <span class="mcc-rw">78,023</span>, <span class="mcc-rw">81,400</span>, <span class="mcc-rw">84,627</span>, <span class="mcc-rw">87,512</span>, <span class="mcc-rw">90,664</span>, <span class="mcc-rw">93,435</span>, <span class="mcc-rw">97,326</span>, <span class="mcc-rw">101,238</span>, <span class="mcc-rw">105,680</span>, <span class="mcc-rw">110,026</span>, <span class="mcc-rw">113,619</span>, <span class="mcc-rw">117,103</span>, <span class="mcc-rw">120,102</span>, <span class="mcc-rw">124,301</span>, <span class="mcc-rw">129,184</span>, <span class="mcc-rw">133,974</span>, <span class="mcc-rw">139,196</span>, <span class="mcc-rw">142,690</span>, <span class="mcc-rw">146,837</span>, <span class="mcc-rw">150,264</span>, <span class="mcc-rw">154,863</span>, <span class="mcc-rw">159,793</span>, <span class="mcc-rw">165,455</span>, <span class="mcc-rw">170,485</span>, <span class="mcc-rw">175,202</span>, <span class="mcc-rw">180,545</span>, <span class="mcc-rw">185,122</span>, <span class="mcc-rw">191,410</span>, <span class="mcc-rw">196,847</span>, <span class="mcc-rw">202,951< ...
# 3 [<span class="mcc-rm">1</span>, <span class="mcc-rm">1</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">4</span>, <span class="mcc-rm">5</span>, <span class="mcc-rm">6</span>, <span class="mcc-rm">8</span>, <span class="mcc-rm">12</span>, <span class="mcc-rm">16</span>, <span class="mcc-rm">20</span>, <span class="mcc-rm">28</span>, <span class="mcc-rm">29</span>, <span class="mcc-rm">37</span>, <span class="mcc-rm">50</span>, <span class="mcc-rm">60</span>, <span class="mcc-rm">79</span>, <span class="mcc-rm">94</span>, <span class="mcc-rm">125</span>, <span class="mcc-rm">141</span>, <span class="mcc-rm">174</span>, <span class="mcc-rm">194</span>, <span class="mcc-rm">233</span>, <span class="mcc-rm">273</span>, <span class="mcc-rm">296</span>, <span class="mcc-rm">332</span>, <span class="mcc-rm">406</span>, <span class="mcc-rm">449</span>, <span class="mcc-rm">486</span>, <span class="mcc-rm">546</span>, <span class="mcc-rm">650</span>, <span class="mcc-rm">686</span>, <span class="mcc-rm">712</span>, <span class="mcc-rm">857</span>, <span class="mcc-rm">970</span>, <span class="mcc-rm">1,069</span>, <span class="mcc-rm">1,221</span>, <span class="mcc-rm">1,305</span>, <span class="mcc-rm">1,351</span>, <span class="mcc-rm">1,434</span>, <span class="mcc-rm">1,569</span>, <span class="mcc-rm">1,732</span>, <span class="mcc-rm">1,859</span>, <span class="mcc-rm">1,972</span>, <span class="mcc-rm">2,061</span>, <span class="mcc-rm">2,154</span>, <span class="mcc-rm">2,271</span>, <span class="mcc-rm">2,507</span>, <span class="mcc-rm">2,704</span>, <span class="mcc-rm">2,961</span>, <span class="mcc-rm">3,160</span>, <span class="mcc-rm">3,353</span>, <span class="mcc-rm">3,465</span>, <span class="mcc-rm">3,573</span>, <span class="mcc-rm">3,926</span>, <span class="mcc-rm">4,220</span>, <span class="mcc-rm">4,477</span>, <span class="mcc-rm">4,767</span>, <span class="mcc-rm">5,045</span>, <span class="mcc-rm">5,177</span>, <span class="mcc-rm">5,332</span>, <span class="mcc-rm">5,666</span>, <span class="mcc-rm">6,090</span>, <span class="mcc-rm">6,510</span>, <span class="mcc-rm">6,989</span>, <span class="mcc-rm">7,179</span>, <span class="mcc-rm">7,394</span>, <span class="mcc-rm">7,633</span>, <span class="mcc-rm">8,134</span>, <span class="mcc-rm">8,597</span>, <span class="mcc-rm">9,044</span>, <span class="mcc-rm">9,415</span>, <span class="mcc-rm">9,779</span>, <span class="mcc-rm">9,930</span>, <span class="mcc-rm">10,167</span>, <span class="mcc-rm">10,637</span>, <span class="mcc-rm">11,729</span>, <span class="mcc-rm">12,545</span>, <span class="mcc-rm">13,170</span>, <span class="mcc-rm">13,511</span>, <span class="mcc-rm">13,699</span>, <span class="mcc-rm">14,053</span>, <span class="mcc-rm">14,649</span>, <span class="mcc-rm">15,357</span>, <span class="mcc-rm">15,944</span>, <span class="mcc-rm">16,448</span>, <span class="mcc-rm">16,872</span>, <span class="mcc-rm">17,141</span>, <span class="mcc-rm">17,580</span>, <span class="mcc-rm">18,310</span>, <span class="mcc-rm">19,080</span>, <span class="mcc-rm">19,747</span>, <span class="mcc-rm">20,394</span>, <span class="mcc-rm">20,781</span>, <span class="mcc-rm">21,825</span>, <span class="mcc-rm">22,584</span>, <span class="mcc-rm">23,377</span>, <span class="mcc-rm">24,324</span>, <span class="mcc-rm">25,060</span>, <span class="mcc-rm">25,779</span>, <span class="mcc-rm">26,381</span>, <span class="mcc-rm">26,648</span>, <span class="mcc-rm">27,121</span>, <span class="mcc-rm">27,769</span>, <span class="mcc-rm">28,510</span>, <span class="mcc-rm">29,189</span>, <span class="mcc-rm">29,843</span>, <span class="mcc-rm">30,366</span>, <span class="mcc-rm">30,639</span>, <span class="mcc-rm">31,119</span>, <span class="mcc-rm">32,014</span>, <span class="mcc-rm">32,796</span>, <span class="mcc-rm">33,526</span>, <span class="mcc-rm">34,191</span>, <span class="mcc-rm">34,730</spa ...
# 4 4(+1)
# 4 [<span class="mcc-rw">3</span>, <span class="mcc-rw">4</span>, <span class="mcc-rw">5</span>, <span class="mcc-rw">5</span>, <span class="mcc-rw">6</span>, <span class="mcc-rw">7</span>, <span class="mcc-rw">7</span>, <span class="mcc-rw">11</span>, <span class="mcc-rw">15</span>, <span class="mcc-rw">26</span>, <span class="mcc-rw">41</span>, <span class="mcc-rw">53</span>, <span class="mcc-rw">78</span>, <span class="mcc-rw">89</span>, <span class="mcc-rw">118</span>, <span class="mcc-rw">164</span>, <span class="mcc-rw">203</span>, <span class="mcc-rw">251</span>, <span class="mcc-rw">316</span>, <span class="mcc-rw">367</span>, <span class="mcc-rw">405</span>, <span class="mcc-rw">475</span>, <span class="mcc-rw">585</span>, <span class="mcc-rw">717</span>, <span class="mcc-rw">848</span>, <span class="mcc-rw">993</span>, <span class="mcc-rw">1,094</span>, <span class="mcc-rw">1,215</span>, <span class="mcc-rw">1,378</span>, <span class="mcc-rw">1,510</span>, <span class="mcc-rw">1,688</span>, <span class="mcc-rw">1,890</span>, <span class="mcc-rw">2,143</span>, <span class="mcc-rw">2,439</span>, <span class="mcc-rw">2,785</span>, <span class="mcc-rw">3,181</span>, <span class="mcc-rw">3,441</span>, <span class="mcc-rw">3,844</span>, <span class="mcc-rw">4,219</span>, <span class="mcc-rw">4,661</span>, <span class="mcc-rw">5,014</span>, <span class="mcc-rw">5,399</span>, <span class="mcc-rw">5,847</span>, <span class="mcc-rw">6,297</span>, <span class="mcc-rw">6,875</span>, <span class="mcc-rw">7,497</span>, <span class="mcc-rw">8,261</span>, <span class="mcc-rw">8,772</span>, <span class="mcc-rw">9,501</span>, <span class="mcc-rw">10,544</span>, <span class="mcc-rw">11,633</span>, <span class="mcc-rw">12,872</span>, <span class="mcc-rw">13,842</span>, <span class="mcc-rw">14,677</span>, <span class="mcc-rw">15,529</span>, <span class="mcc-rw">16,752</span>, <span class="mcc-rw">17,799</span>, <span class="mcc-rw">19,224</span>, <span class="mcc-rw">20,739</span>, <span class="mcc-rw">22,088</span>, <span class="mcc-rw">23,471</span>, <span class="mcc-rw">24,905</span>, <span class="mcc-rw">26,025</span>, <span class="mcc-rw">27,634</span>, <span class="mcc-rw">29,616</span>, <span class="mcc-rw">31,522</span>, <span class="mcc-rw">33,460</span>, <span class="mcc-rw">35,022</span>, <span class="mcc-rw">36,327</span>, <span class="mcc-rw">38,324</span>, <span class="mcc-rw">40,186</span>, <span class="mcc-rw">42,595</span>, <span class="mcc-rw">45,032</span>, <span class="mcc-rw">47,144</span>, <span class="mcc-rw">49,219</span>, <span class="mcc-rw">51,633</span>, <span class="mcc-rw">54,346</span>, <span class="mcc-rw">56,594</span>, <span class="mcc-rw">59,567</span>, <span class="mcc-rw">62,527</span>, <span class="mcc-rw">65,856</span>, <span class="mcc-rw">68,620</span>, <span class="mcc-rw">71,105</span>, <span class="mcc-rw">74,560</span>, <span class="mcc-rw">78,023</span>, <span class="mcc-rw">81,400</span>, <span class="mcc-rw">84,627</span>, <span class="mcc-rw">87,512</span>, <span class="mcc-rw">90,664</span>, <span class="mcc-rw">93,435</span>, <span class="mcc-rw">97,326</span>, <span class="mcc-rw">101,238</span>, <span class="mcc-rw">105,680</span>, <span class="mcc-rw">110,026</span>, <span class="mcc-rw">113,619</span>, <span class="mcc-rw">117,103</span>, <span class="mcc-rw">120,102</span>, <span class="mcc-rw">124,301</span>, <span class="mcc-rw">129,184</span>, <span class="mcc-rw">133,974</span>, <span class="mcc-rw">139,196</span>, <span class="mcc-rw">142,690</span>, <span class="mcc-rw">146,837</span>, <span class="mcc-rw">150,264</span>, <span class="mcc-rw">154,863</span>, <span class="mcc-rw">159,793</span>, <span class="mcc-rw">165,455</span>, <span class="mcc-rw">170,485</span>, <span class="mcc-rw">175,202</span>, <span class="mcc-rw">180,545</span>, <span class="mcc-rw">185,122</span>, <span class="mcc-rw">191,410</span>, <span class="mcc-rw">196,847</span>, <span class="mcc-rw">202,951< ...
# 4 [<span class="mcc-rm">1</span>, <span class="mcc-rm">1</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">4</span>, <span class="mcc-rm">5</span>, <span class="mcc-rm">6</span>, <span class="mcc-rm">8</span>, <span class="mcc-rm">12</span>, <span class="mcc-rm">16</span>, <span class="mcc-rm">20</span>, <span class="mcc-rm">28</span>, <span class="mcc-rm">29</span>, <span class="mcc-rm">37</span>, <span class="mcc-rm">50</span>, <span class="mcc-rm">60</span>, <span class="mcc-rm">79</span>, <span class="mcc-rm">94</span>, <span class="mcc-rm">125</span>, <span class="mcc-rm">141</span>, <span class="mcc-rm">174</span>, <span class="mcc-rm">194</span>, <span class="mcc-rm">233</span>, <span class="mcc-rm">273</span>, <span class="mcc-rm">296</span>, <span class="mcc-rm">332</span>, <span class="mcc-rm">406</span>, <span class="mcc-rm">449</span>, <span class="mcc-rm">486</span>, <span class="mcc-rm">546</span>, <span class="mcc-rm">650</span>, <span class="mcc-rm">686</span>, <span class="mcc-rm">712</span>, <span class="mcc-rm">857</span>, <span class="mcc-rm">970</span>, <span class="mcc-rm">1,069</span>, <span class="mcc-rm">1,221</span>, <span class="mcc-rm">1,305</span>, <span class="mcc-rm">1,351</span>, <span class="mcc-rm">1,434</span>, <span class="mcc-rm">1,569</span>, <span class="mcc-rm">1,732</span>, <span class="mcc-rm">1,859</span>, <span class="mcc-rm">1,972</span>, <span class="mcc-rm">2,061</span>, <span class="mcc-rm">2,154</span>, <span class="mcc-rm">2,271</span>, <span class="mcc-rm">2,507</span>, <span class="mcc-rm">2,704</span>, <span class="mcc-rm">2,961</span>, <span class="mcc-rm">3,160</span>, <span class="mcc-rm">3,353</span>, <span class="mcc-rm">3,465</span>, <span class="mcc-rm">3,573</span>, <span class="mcc-rm">3,926</span>, <span class="mcc-rm">4,220</span>, <span class="mcc-rm">4,477</span>, <span class="mcc-rm">4,767</span>, <span class="mcc-rm">5,045</span>, <span class="mcc-rm">5,177</span>, <span class="mcc-rm">5,332</span>, <span class="mcc-rm">5,666</span>, <span class="mcc-rm">6,090</span>, <span class="mcc-rm">6,510</span>, <span class="mcc-rm">6,989</span>, <span class="mcc-rm">7,179</span>, <span class="mcc-rm">7,394</span>, <span class="mcc-rm">7,633</span>, <span class="mcc-rm">8,134</span>, <span class="mcc-rm">8,597</span>, <span class="mcc-rm">9,044</span>, <span class="mcc-rm">9,415</span>, <span class="mcc-rm">9,779</span>, <span class="mcc-rm">9,930</span>, <span class="mcc-rm">10,167</span>, <span class="mcc-rm">10,637</span>, <span class="mcc-rm">11,729</span>, <span class="mcc-rm">12,545</span>, <span class="mcc-rm">13,170</span>, <span class="mcc-rm">13,511</span>, <span class="mcc-rm">13,699</span>, <span class="mcc-rm">14,053</span>, <span class="mcc-rm">14,649</span>, <span class="mcc-rm">15,357</span>, <span class="mcc-rm">15,944</span>, <span class="mcc-rm">16,448</span>, <span class="mcc-rm">16,872</span>, <span class="mcc-rm">17,141</span>, <span class="mcc-rm">17,580</span>, <span class="mcc-rm">18,310</span>, <span class="mcc-rm">19,080</span>, <span class="mcc-rm">19,747</span>, <span class="mcc-rm">20,394</span>, <span class="mcc-rm">20,781</span>, <span class="mcc-rm">21,825</span>, <span class="mcc-rm">22,584</span>, <span class="mcc-rm">23,377</span>, <span class="mcc-rm">24,324</span>, <span class="mcc-rm">25,060</span>, <span class="mcc-rm">25,779</span>, <span class="mcc-rm">26,381</span>, <span class="mcc-rm">26,648</span>, <span class="mcc-rm">27,121</span>, <span class="mcc-rm">27,769</span>, <span class="mcc-rm">28,510</span>, <span class="mcc-rm">29,189</span>, <span class="mcc-rm">29,843</span>, <span class="mcc-rm">30,366</span>, <span class="mcc-rm">30,639</span>, <span class="mcc-rm">31,119</span>, <span class="mcc-rm">32,014</span>, <span class="mcc-rm">32,796</span>, <span class="mcc-rm">33,526</span>, <span class="mcc-rm">34,191</span>, <span class="mcc-rm">34,730</spa ...
# 5
#
# 5 [<span class="mcc-rw">3</span>, <span class="mcc-rw">4</span>, <span class="mcc-rw">5</span>, <span class="mcc-rw">5</span>, <span class="mcc-rw">6</span>, <span class="mcc-rw">7</span>, <span class="mcc-rw">7</span>, <span class="mcc-rw">11</span>, <span class="mcc-rw">15</span>, <span class="mcc-rw">26</span>, <span class="mcc-rw">41</span>, <span class="mcc-rw">53</span>, <span class="mcc-rw">78</span>, <span class="mcc-rw">89</span>, <span class="mcc-rw">118</span>, <span class="mcc-rw">164</span>, <span class="mcc-rw">203</span>, <span class="mcc-rw">251</span>, <span class="mcc-rw">316</span>, <span class="mcc-rw">367</span>, <span class="mcc-rw">405</span>, <span class="mcc-rw">475</span>, <span class="mcc-rw">585</span>, <span class="mcc-rw">717</span>, <span class="mcc-rw">848</span>, <span class="mcc-rw">993</span>, <span class="mcc-rw">1,094</span>, <span class="mcc-rw">1,215</span>, <span class="mcc-rw">1,378</span>, <span class="mcc-rw">1,510</span>, <span class="mcc-rw">1,688</span>, <span class="mcc-rw">1,890</span>, <span class="mcc-rw">2,143</span>, <span class="mcc-rw">2,439</span>, <span class="mcc-rw">2,785</span>, <span class="mcc-rw">3,181</span>, <span class="mcc-rw">3,441</span>, <span class="mcc-rw">3,844</span>, <span class="mcc-rw">4,219</span>, <span class="mcc-rw">4,661</span>, <span class="mcc-rw">5,014</span>, <span class="mcc-rw">5,399</span>, <span class="mcc-rw">5,847</span>, <span class="mcc-rw">6,297</span>, <span class="mcc-rw">6,875</span>, <span class="mcc-rw">7,497</span>, <span class="mcc-rw">8,261</span>, <span class="mcc-rw">8,772</span>, <span class="mcc-rw">9,501</span>, <span class="mcc-rw">10,544</span>, <span class="mcc-rw">11,633</span>, <span class="mcc-rw">12,872</span>, <span class="mcc-rw">13,842</span>, <span class="mcc-rw">14,677</span>, <span class="mcc-rw">15,529</span>, <span class="mcc-rw">16,752</span>, <span class="mcc-rw">17,799</span>, <span class="mcc-rw">19,224</span>, <span class="mcc-rw">20,739</span>, <span class="mcc-rw">22,088</span>, <span class="mcc-rw">23,471</span>, <span class="mcc-rw">24,905</span>, <span class="mcc-rw">26,025</span>, <span class="mcc-rw">27,634</span>, <span class="mcc-rw">29,616</span>, <span class="mcc-rw">31,522</span>, <span class="mcc-rw">33,460</span>, <span class="mcc-rw">35,022</span>, <span class="mcc-rw">36,327</span>, <span class="mcc-rw">38,324</span>, <span class="mcc-rw">40,186</span>, <span class="mcc-rw">42,595</span>, <span class="mcc-rw">45,032</span>, <span class="mcc-rw">47,144</span>, <span class="mcc-rw">49,219</span>, <span class="mcc-rw">51,633</span>, <span class="mcc-rw">54,346</span>, <span class="mcc-rw">56,594</span>, <span class="mcc-rw">59,567</span>, <span class="mcc-rw">62,527</span>, <span class="mcc-rw">65,856</span>, <span class="mcc-rw">68,620</span>, <span class="mcc-rw">71,105</span>, <span class="mcc-rw">74,560</span>, <span class="mcc-rw">78,023</span>, <span class="mcc-rw">81,400</span>, <span class="mcc-rw">84,627</span>, <span class="mcc-rw">87,512</span>, <span class="mcc-rw">90,664</span>, <span class="mcc-rw">93,435</span>, <span class="mcc-rw">97,326</span>, <span class="mcc-rw">101,238</span>, <span class="mcc-rw">105,680</span>, <span class="mcc-rw">110,026</span>, <span class="mcc-rw">113,619</span>, <span class="mcc-rw">117,103</span>, <span class="mcc-rw">120,102</span>, <span class="mcc-rw">124,301</span>, <span class="mcc-rw">129,184</span>, <span class="mcc-rw">133,974</span>, <span class="mcc-rw">139,196</span>, <span class="mcc-rw">142,690</span>, <span class="mcc-rw">146,837</span>, <span class="mcc-rw">150,264</span>, <span class="mcc-rw">154,863</span>, <span class="mcc-rw">159,793</span>, <span class="mcc-rw">165,455</span>, <span class="mcc-rw">170,485</span>, <span class="mcc-rw">175,202</span>, <span class="mcc-rw">180,545</span>, <span class="mcc-rw">185,122</span>, <span class="mcc-rw">191,410</span>, <span class="mcc-rw">196,847</span>, <span class="mcc-rw">202,951< ...
# 5 [<span class="mcc-rm">1</span>, <span class="mcc-rm">1</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">2</span>, <span class="mcc-rm">4</span>, <span class="mcc-rm">5</span>, <span class="mcc-rm">6</span>, <span class="mcc-rm">8</span>, <span class="mcc-rm">12</span>, <span class="mcc-rm">16</span>, <span class="mcc-rm">20</span>, <span class="mcc-rm">28</span>, <span class="mcc-rm">29</span>, <span class="mcc-rm">37</span>, <span class="mcc-rm">50</span>, <span class="mcc-rm">60</span>, <span class="mcc-rm">79</span>, <span class="mcc-rm">94</span>, <span class="mcc-rm">125</span>, <span class="mcc-rm">141</span>, <span class="mcc-rm">174</span>, <span class="mcc-rm">194</span>, <span class="mcc-rm">233</span>, <span class="mcc-rm">273</span>, <span class="mcc-rm">296</span>, <span class="mcc-rm">332</span>, <span class="mcc-rm">406</span>, <span class="mcc-rm">449</span>, <span class="mcc-rm">486</span>, <span class="mcc-rm">546</span>, <span class="mcc-rm">650</span>, <span class="mcc-rm">686</span>, <span class="mcc-rm">712</span>, <span class="mcc-rm">857</span>, <span class="mcc-rm">970</span>, <span class="mcc-rm">1,069</span>, <span class="mcc-rm">1,221</span>, <span class="mcc-rm">1,305</span>, <span class="mcc-rm">1,351</span>, <span class="mcc-rm">1,434</span>, <span class="mcc-rm">1,569</span>, <span class="mcc-rm">1,732</span>, <span class="mcc-rm">1,859</span>, <span class="mcc-rm">1,972</span>, <span class="mcc-rm">2,061</span>, <span class="mcc-rm">2,154</span>, <span class="mcc-rm">2,271</span>, <span class="mcc-rm">2,507</span>, <span class="mcc-rm">2,704</span>, <span class="mcc-rm">2,961</span>, <span class="mcc-rm">3,160</span>, <span class="mcc-rm">3,353</span>, <span class="mcc-rm">3,465</span>, <span class="mcc-rm">3,573</span>, <span class="mcc-rm">3,926</span>, <span class="mcc-rm">4,220</span>, <span class="mcc-rm">4,477</span>, <span class="mcc-rm">4,767</span>, <span class="mcc-rm">5,045</span>, <span class="mcc-rm">5,177</span>, <span class="mcc-rm">5,332</span>, <span class="mcc-rm">5,666</span>, <span class="mcc-rm">6,090</span>, <span class="mcc-rm">6,510</span>, <span class="mcc-rm">6,989</span>, <span class="mcc-rm">7,179</span>, <span class="mcc-rm">7,394</span>, <span class="mcc-rm">7,633</span>, <span class="mcc-rm">8,134</span>, <span class="mcc-rm">8,597</span>, <span class="mcc-rm">9,044</span>, <span class="mcc-rm">9,415</span>, <span class="mcc-rm">9,779</span>, <span class="mcc-rm">9,930</span>, <span class="mcc-rm">10,167</span>, <span class="mcc-rm">10,637</span>, <span class="mcc-rm">11,729</span>, <span class="mcc-rm">12,545</span>, <span class="mcc-rm">13,170</span>, <span class="mcc-rm">13,511</span>, <span class="mcc-rm">13,699</span>, <span class="mcc-rm">14,053</span>, <span class="mcc-rm">14,649</span>, <span class="mcc-rm">15,357</span>, <span class="mcc-rm">15,944</span>, <span class="mcc-rm">16,448</span>, <span class="mcc-rm">16,872</span>, <span class="mcc-rm">17,141</span>, <span class="mcc-rm">17,580</span>, <span class="mcc-rm">18,310</span>, <span class="mcc-rm">19,080</span>, <span class="mcc-rm">19,747</span>, <span class="mcc-rm">20,394</span>, <span class="mcc-rm">20,781</span>, <span class="mcc-rm">21,825</span>, <span class="mcc-rm">22,584</span>, <span class="mcc-rm">23,377</span>, <span class="mcc-rm">24,324</span>, <span class="mcc-rm">25,060</span>, <span class="mcc-rm">25,779</span>, <span class="mcc-rm">26,381</span>, <span class="mcc-rm">26,648</span>, <span class="mcc-rm">27,121</span>, <span class="mcc-rm">27,769</span>, <span class="mcc-rm">28,510</span>, <span class="mcc-rm">29,189</span>, <span class="mcc-rm">29,843</span>, <span class="mcc-rm">30,366</span>, <span class="mcc-rm">30,639</span>, <span class="mcc-rm">31,119</span>, <span class="mcc-rm">32,014</span>, <span class="mcc-rm">32,796</span>, <span class="mcc-rm">33,526</span>, <span class="mcc-rm">34,191</span>, <span class="mcc-rm">34,730</spa ...
# fechas:  <class 'bs4.element.ResultSet'>
# Numero de datos recuperados 0, enfermos + muertos

# %%
#Verificamos que tengamos los datos
print("Resultado de recuperacion de datos, los tres deben ser iguales:\n")
print(f"Número de datos de fecha: {len(dates)}")
print(f"Número de datos de enfermos: {len(enfermos)}")
print(f"Número de datos de muertos: {len(muertos)}")

#print(enfermos)
#print(muertos)
#print(dates)
# Out:
# Resultado de recuperacion de datos, los tres deben ser iguales:
#
# Número de datos de fecha: 0
# Número de datos de enfermos: 0
# Número de datos de muertos: 0

# %% [markdown]
# #Gráfica Enfermos
# Tenemos un artefacto en 2020-10-05

# %%
#Como tenemos algunas fechas faltantes, vamos a cortas los primeros 7 datos, donde han inconsistencias
#plt.pĺot(x,y) donde x es una lista de fechas y 'y' es una lista datos

#Graficamos la curva general de enfemos cortando los primeros siete datos
##Primero los datos son texto, debemos convertirlos a fechas y numeros
#empecemos con los enfermos y recortamos los primeros 7 datos

plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(28))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(100000))
plt.xticks(rotation=70)
plt.grid(b=True, color='r')
plt.title("Grafica de Enfermos Totales")
#plt.rcParams['figure.figsize'] = [20, 20] #inches
plt.plot(dates[7:],enfermos[7:])
#plt.plot(dates[7:],enfermos[7:])
#plt.plot(dates[7:],enfermos[7:])

# %%
# Aqui impimimos el total de enfermos 
d_enfermos={}
print(f"Total de datos: {len(dates[7:])}: \n") #Cortamos los primeros 7 por inconsistencias
for i in range(7,len(dates)):
    d_enfermos[dates[i]]=enfermos[i]
    #print(f"{dates[i]} : {enfermos[i]}")

#print(d_enfermos)
# Out:
# Total de datos: 0:

# %% [markdown]
# #Grafica Muertos

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(28))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(10000))
plt.xticks(rotation=70)
plt.grid(b=True, color='r')
plt.title("Grafica de muertos totales")

plt.plot(dates[7:],muertos[7:])
#print("Gráfica de muertos totales")

# %%
#Ahora impimimos El numero de muertos totales
d_muertos={}
print(f"Total de datos: {len(dates[7:])}: \n") #Cortamos los primero 7 por incosistencias
for i in range(7,len(dates)):
    d_muertos[dates[i]]=muertos[i]
    #print(f"{dates[i]} : {muertos[i]}")
#print(d_muertos)
# Out:
# Total de datos: 0:

# %% [markdown]
# #Incrementos Diarios

# %% [markdown]
# Ahora que tenemos los datos, generamos el pasto, tanto para los muertos como para los enfermos, el pasto es la diferencia o incremento y debe ser igual al numero de elementos -1
# primero obtenemos el numero de elementos (actual menos anterior)

# %%
pasto_enfermos=[]
pasto_muertos=[]
longitud=len(enfermos)-1 #para no salirnos del indice
#print(longitud)
for i in range(0,longitud):
    #pasto = b - a 
    pasto_enfermos.append(enfermos[i+1]-enfermos[i])
    #ahora lo mismo para los muertos
    pasto_muertos.append(muertos[i+1]-muertos[i])
    
#print(f"Incremento diario en enfermos durante {len(pasto_enfermos)} dias:")        
#print(pasto_enfermos)
#print(f"Incremento diario en muertos durante {len(pasto_muertos)} días:")
#print(pasto_muertos)

# %% [markdown]
# ##Incremento diario en enfermos

# %%
#Ahora Graficamos el incremento diario de enfermos
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(14))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(1000))
plt.xticks(rotation=70)
plt.grid(b=True, color='r')
plt.title("Gráfica de incrementos diarios en enfermos")
plt.plot(dates[7:],pasto_enfermos[6:])

# %% [markdown]
# ## Ajsute ##
# Debido a un ajuste de casos no contabilizados que realizo el gobierno mexicano, tenemos un excesivo aumento de casos el dia 2020-10-05 con un total de 28115 casos en un dia, para efectos de de la gráfica este dato se sustituyo por el proemedio aritmentico de la suma del dia anterior y posterios (3712 + 4828)/2 = 4270

# %%
from copy import deepcopy
pe2 = deepcopy(pasto_enfermos)
#checamos que el elemnto existainqu
if pe2.count(28115.0) == 1:
    #si exsite substituimos el elemento por el promedio:
    #print(pe2[pe2.index(28115.0)])
    pe2[pe2.index(28115.0)]= 4270
#verficamos el cambio en el idice 214
#print(pe2[214])
#pe2.count(28115.0)

#ahora Graficamos sin el artefacto

# %%
#Ahora Graficamos el incremeinqunto diario de enfermos sin el artefacto
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(14))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(1000))
plt.xticks(rotation=70)
plt.grid(b=True, color='r')
plt.title("Gráfica de incrementos diarios en enfermos sin artefacto")
plt.plot(dates[7:],pe2[6:])

# %%
#Vamos recuperar los datos de la gráfica
#Primero creamos un dicionario con los datos
delta_enfermos={}
#Luego lo llenamos
print(f"Incremento diario en enfermos durante: {len(dates[7:])} dias\n") #cortamos los primeros siete dias por inconsistencias
for i in range (7,len(dates)):
    delta_enfermos[dates[i]]=pasto_enfermos[i-1]
#Ahora Imprimimos la delta de enfermos

#for key in delta_enfermos:
#    print(f"{key} : {delta_enfermos[key]}")
#print(delta_enfermos)
# Out:
# Incremento diario en enfermos durante: 0 dias

# %% [markdown]
# ##Incremento diario en muertos

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(14))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(200))
plt.xticks(rotation=70)
plt.grid(b=True, color='r')
plt.title("Gráfica de incrementos diarios en muertos")
plt.plot(dates[7:],pasto_muertos[6:])

# %% [markdown]
# ## Ajsute ##
# Debido a un ajuste de casos no contabilizados que realizo el gobierno mexicano, tenemos un excesivo aumento de casos el dia 2020-10-05 con un total de 2789 casos en un dia, para efectos de de la gráfica este dato se sustituyo por el proemedio aritmentico de la suma del dia anterior y posterios (208 + 471)/2 = 339

# %%
from copy import deepcopy
pm = deepcopy(pasto_muertos)
#checamos que el elemnto existainqu
if pm.count(2789.0) == 1:
    #si exsite substituimos el elemento por el promedio:
    #print(pm[pm.index(2789.0)])
    pm[pm.index(2789.0)]= 339
#verficamos el cambio en el idice 214
#print(pm[214])
#pm.count(2789.0)

#ahora Graficamos sin el artefacto
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(14))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(200))
plt.xticks(rotation=70)
plt.grid(b=True, color='r')
plt.title("Gráfica de incrementos diarios en muertos sin artefacto")
plt.plot(dates[7:],pm[6:])

# %%
#ahora imprimimos los datos del incremento de muertos
print(f"Incremento diario en muertos durante {len(dates[7:])} dias\n")
delta_muertos={} #diccionario para guardar el pasto de los muertos
for i in range (7,len(dates)):
    delta_muertos[dates[i]]=pasto_muertos[i-1]
    #print(f"{dates[i]} : {pasto_muertos[i-1]}" )
#print(delta_muertos)
# Out:
# Incremento diario en muertos durante 0 dias

# %% [markdown]
# #Exportancion de la informacion a formato CSV para ser leida por excel y similares

# %%
#guardamos la informacion en formato CSV para ser leida por excel
excel_enfermos = pd.DataFrame.from_dict(d_enfermos, orient="index")
excel_muertos = pd.DataFrame.from_dict(d_muertos, orient="index")
excel_delta_enfermos = pd.DataFrame.from_dict(delta_enfermos, orient="index")
excel_delta_muertos = pd.DataFrame.from_dict(delta_muertos, orient="index")

#Auqui guardamos la informacion en formato CSV
excel_enfermos.to_csv("Total de enfermos.csv")
excel_muertos.to_csv("Total de muertos.csv")
excel_delta_enfermos.to_csv("Incremento en enfermos.csv")
excel_delta_muertos.to_csv("Incremento en muertos.csv")

# %% [markdown]
# #Analisis por dia de la semana
#
# Ahora vamos a tratar de hacer analisis acumulativos por dia lunes, martes, etc,  sumando todos los enfermos del dia durante toda la pandemia y graficandolos por tipo de día.

# %%
#primero creamos una funcion que nos regrese al dia de la semana desde una string con fromato
#YYYY-MM-DD
import calendar
def day_of_week(fecha="2020-06-21"):
    """Esta funcion recibe un string de fecha en formato yyyy-mm-dd y debe regresar un entero
    con el dia de la semana, 0 para domingo, 1 para lunes, ..., 6 para sabado """
    year, month, day = (int(i) for i in fecha.split("-"))
    return calendar.weekday(year, month, day)
day_of_week()

#ya que tenemos el dia de la semana, creamos una funcion que regrese un diccionario 
#con los acumulados por dia de cada uno de los conjuntos de datos, la funcion
#debe recibir un conjunto de datos y regresar un diccionario con llaves por cada
#dia y el acumulado durante el periodo

def acumulados_por_dia(dict_datos):
    """ El diccionarion de datos debe tener el formato YYYY-MM-DD:dato, para varios dias"""
    #creamos los contenedores de datos, una lista para cada uno:
    lunes, martes, miercoles, jueves, viernes, sabado, domingo=[],[],[],[],[],[],[]
    #ahora recorremos el diccionario de datos
    for key in dict_datos:
        if day_of_week(key) == 0:
            domingo.append(dict_datos[key])
        if day_of_week(key) == 1:
            lunes.append(dict_datos[key])
        if day_of_week(key) == 2:
            martes.append(dict_datos[key])
        if day_of_week(key) == 3:
            miercoles.append(dict_datos[key])
        if day_of_week(key) == 4:
            jueves.append(dict_datos[key])
        if day_of_week(key) == 5:
            viernes.append(dict_datos[key])
        if day_of_week(key) == 6:
            sabado.append(dict_datos[key])
    #ahora creamos un diccionario para guardar los datos 
    salida={}
    salida["Lunes"]=sum(lunes)
    salida["Martes"]=sum(martes)
    salida["Miercoles"]=sum(miercoles)
    salida["Jueves"]=sum(jueves)
    salida["Viernes"]=sum(viernes)
    salida["Sabado"]=sum(sabado)
    salida["Domingo"]=sum(domingo)
    return salida
acc_enfermos=acumulados_por_dia(delta_enfermos)
acc_muertos=acumulados_por_dia(delta_muertos)

# %% [markdown]
# #grafica de enfermos acumulados por dia

# %%
print(acc_enfermos)
print(f"Total de enfermos: {sum(acc_enfermos.values())}")
plt.figure(figsize=(15,10))
plt.title("Gráfica de enfermos acumulados por dia de la semana")
plt.bar(acc_enfermos.keys(), acc_enfermos.values())
# Out:
# {'Lunes': 0, 'Martes': 0, 'Miercoles': 0, 'Jueves': 0, 'Viernes': 0, 'Sabado': 0, 'Domingo': 0}
# Total de enfermos: 0
# <BarContainer object of 7 artists>

# %% [markdown]
# #Grafica de Muerstos acumulados por dia

# %%
print(acc_muertos)
print(f"Total de muertos: {sum(acc_muertos.values())}")
plt.figure(figsize=(15,10))
plt.title("Gráfica de muertos acumulados por dia de la semana")
plt.bar(acc_muertos.keys(),acc_muertos.values())
# Out:
# {'Lunes': 0, 'Martes': 0, 'Miercoles': 0, 'Jueves': 0, 'Viernes': 0, 'Sabado': 0, 'Domingo': 0}
# Total de muertos: 0
# <BarContainer object of 7 artists>

# %% [markdown]
# #Grafica de enfermos por dia de la semana
#
# Vamos a graficar los reportes de enfermos por dia de la semana
#
# Creamos una funcion para graficar obtener los datos, es similar a la de accumulados por dia
# pero sin la sumatoria final.

# %%
def acc2(dict_datos):
    """ El diccionarion de datos debe tener el formato YYYY-MM-DD:dato, para varios dias"""
    #creamos los contenedores de datos, una lista para cada uno:
    lunes, martes, miercoles, jueves, viernes, sabado, domingo=[],[],[],[],[],[],[]
    #ahora recorremos el diccionario de datos
    for key in dict_datos:
        if day_of_week(key) == 0:
            domingo.append(dict_datos[key])
        if day_of_week(key) == 1:
            lunes.append(dict_datos[key])
        if day_of_week(key) == 2:
            martes.append(dict_datos[key])
        if day_of_week(key) == 3:
            miercoles.append(dict_datos[key])
        if day_of_week(key) == 4:
            jueves.append(dict_datos[key])
        if day_of_week(key) == 5:
            viernes.append(dict_datos[key])
        if day_of_week(key) == 6:
            sabado.append(dict_datos[key])
    #ahora creamos un diccionario para guardar los datos 
    salida={}
    salida["Lunes"]=lunes
    salida["Martes"]=martes
    salida["Miercoles"]=miercoles
    salida["Jueves"]=jueves
    salida["Viernes"]=viernes
    salida["Sabado"]=sabado
    salida["Domingo"]=domingo
    return salida

DiasEnfermos=acc2(delta_enfermos)
#print(DiasEnfermos)

# %%
plt.figure(figsize=(15,10))
plt.plot(DiasEnfermos["Lunes"], label="Lunes")
plt.plot(DiasEnfermos["Martes"], label="Martes")
plt.plot(DiasEnfermos["Miercoles"], label="Miercoles")
plt.plot(DiasEnfermos["Jueves"], label="Jueves")
plt.plot(DiasEnfermos["Viernes"], label="Viernes")
plt.plot(DiasEnfermos["Sabado"], label="Sabado")
plt.plot(DiasEnfermos["Domingo"], label="Domingo")
plt.grid(b=True, color='r')
plt.title("Gráfica de enfermos por dia de la semana")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, frameon=False)

# %% [markdown]
# #Gráfica de Muertos por dia de la semana

# %%
DiasMuertos=acc2(delta_muertos)
print(DiasMuertos)
# Out:
# {'Lunes': [], 'Martes': [], 'Miercoles': [], 'Jueves': [], 'Viernes': [], 'Sabado': [], 'Domingo': []}

# %%
plt.figure(figsize=(15,10))
plt.plot(DiasMuertos["Lunes"], label="Lunes")
plt.plot(DiasMuertos["Martes"], label="Martes")
plt.plot(DiasMuertos["Miercoles"], label="Miercoles")
plt.plot(DiasMuertos["Jueves"], label="Jueves")
plt.plot(DiasMuertos["Viernes"], label="Viernes")
plt.plot(DiasMuertos["Sabado"], label="Sabado")
plt.plot(DiasMuertos["Domingo"], label="Domingo")
plt.grid(b=True, color='r')
plt.title("Gráfica de muertos por dia de la semana")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, frameon=False)
